# %% [markdown]
# # **CVPS20 // Sliding Window Object Detector**
#
# *December 1, 2020*
#
# This notebook introduces the concept of a sliding window detector, using a CNN as the feature extractor and classifier for each window.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
plt.rcParams["figure.figsize"] = [10, 8]
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gist_gray"

# %% [markdown]
# Let's load in the scanning probe microscope data that we used in the last assignment,

# %%
# -- load data
data = np.load("/content/drive/MyDrive/cvps20/data/spm/train_good_all.npy")

# %%
# -- visualize some examples
fig, ax = plt.subplots(2, 4, figsize=[10, 5], sharex=True, sharey=True)
for ii in range(8):
  ax[ii // 4, ii % 4].imshow(data[ii])
fig.show()

# %% [markdown]
# Our goal will be to build an **object detector** to find those magnesium phthalocyanine (MgPc) molecules in a given image.

# %% [markdown]
# First we normalize the images,

# %%
# -- normalize
norm = (data - data.min(axis=(1, 2), keepdims=True)) / (data.max(axis=(1, 2), keepdims=True) - data.min(axis=(1, 2), keepdims=True))

# %%
norm[30].min()
# Out:
# 0.0

# %% [markdown]
# Now we load the pre-labeled MgPc positive and negative locations,

# %%
# -- load the pos and neg locations
pos = np.load("/content/drive/MyDrive/cvps20/data/spm/spm_struct_pos.npy")
neg = np.load("/content/drive/MyDrive/cvps20/data/spm/spm_struct_neg.npy")

# %%
pos
# Out:
# array([[  30,   25,   51],
#        [  32,   33, 1136],
#        [  16,   52,  186],
#        ...,
#        [  25,   23,  407],
#        [  31,   35, 1184],
#        [  39,   32,  982]])

# %%
plt.imshow(norm[51])

# %% [markdown]
# Using these locations, we can create postage stamps of examples of MgPc molecules and background,

# %%
# -- create pos postage stamps
wid = 10
stmp_pos = []
for ii in range(pos.shape[0]):
  trow, tcol, tind = pos[ii]

  if (trow > wid) & (trow < 64 - wid) & (tcol > wid) & (tcol < 64 - wid):
    stmp_pos.append(norm[tind, trow-wid:trow+wid, tcol-wid:tcol+wid])

stmp_pos = np.array(stmp_pos)

# %%
# -- create neg postage stamps
stmp_neg = []
for ii in range(neg.shape[0]):
  trow, tcol, tind = neg[ii]

  if (trow > wid) & (trow < 64 - wid) & (tcol > wid) & (tcol < 64 - wid):
    stmp_neg.append(norm[tind, trow-wid:trow+wid, tcol-wid:tcol+wid])

stmp_neg = np.array(stmp_neg)

# %%
# -- plot some positive examples
fig, ax = plt.subplots(10, 10)
for ii in range(100):
  ax[ii // 10, ii % 10].imshow(stmp_pos[ii])
  ax[ii // 10, ii % 10].axis("off")
fig.show()

# %%
# -- plot some negative examples
fig, ax = plt.subplots(10, 10)
for ii in range(100):
  ax[ii // 10, ii % 10].imshow(stmp_neg[ii])
  ax[ii // 10, ii % 10].axis("off")
fig.show()

# %% [markdown]
# Now we build a classifier that, for a given proposal location, would classify a positive or negative MgPc detection,

# %%
# -- create a training/testing set
feat = np.concatenate((stmp_neg, stmp_pos), axis=0)
targ = np.concatenate((np.full(stmp_neg.shape[0], 0), np.full(stmp_pos.shape[0], 1)))
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, random_state=302)
feat_tr = feat_tr.reshape(feat_tr.shape[0], feat_tr.shape[1], feat_tr.shape[2], 1)
feat_te = feat_te.reshape(feat_te.shape[0], feat_te.shape[1], feat_te.shape[2], 1)

# %%
# -- build a simple CNN
layer1 = keras.layers.Conv2D(16, kernel_size=(5, 5), padding="same", activation="relu", input_shape=(2 * wid, 2 * wid, 1), kernel_regularizer=keras.regularizers.l2(0.001))
layer2 = keras.layers.MaxPool2D(2)
layer3 = keras.layers.Conv2D(32, kernel_size=(5, 5), padding="same", activation="relu", kernel_regularizer=keras.regularizers.l2(0.001))
layer4 = keras.layers.MaxPool2D(2)
layer5 = keras.layers.Flatten()
layer6 = keras.layers.Dense(64, activation="relu",kernel_regularizer=keras.regularizers.l2(0.001))
layer7 = keras.layers.Dense(2, activation="softmax")
layers = [layer1, layer2, layer3, layer4, layer5, layer6, layer7]

# -- instantiate the model
model = keras.Sequential(layers)
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# -- fit the model
history = model.fit(feat_tr, targ_tr, epochs=50, validation_split=0.1, batch_size=50)

# -- print the accuracy
loss_tr, acc_tr = model.evaluate(feat_tr, targ_tr)
loss_te, acc_te = model.evaluate(feat_te, targ_te)

print("Training accuracy : {0:.4f}".format(acc_tr))
print("Testing accuracy  : {0:.4f}".format(acc_te))

# -- plot the accuracy
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.ylabel("testing accuray")
plt.xlabel("epoch")
# Out:
# Epoch 1/50
# 12/12 [==============================] - 0s 21ms/step - loss: 0.6953 - accuracy: 0.7148 - val_loss: 0.5164 - val_accuracy: 0.9242
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4968 - accuracy: 0.9185 - val_loss: 0.3641 - val_accuracy: 0.9242
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3603 - accuracy: 0.9236 - val_loss: 0.3410 - val_accuracy: 0.8939
# Epoch 4/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3213 - accuracy: 0.9134 - val_loss: 0.2984 - val_accuracy: 0.9091
# Epoch 5/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2693 - accuracy: 0.9440 - val_loss: 0.2693 - val_accuracy: 0.8939
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2331 - accuracy: 0.9525 - val_loss: 0.2392 - val_accuracy: 0.9242
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2255 - accuracy: 0.9593 - val_loss: 0.2354 - val_accuracy: 0.9394
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1996 - accuracy: 0.9677 - val_loss: 0.2167 - val_accuracy: 0.9545
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1722 - accuracy: 0.9830 - val_loss: 0.2034 - val_accuracy: 0.9394
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1605 - accuracy: 0.9813 - val_loss: 0.2103 - val_accuracy: 0.9697
# Epoch 11/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1480 - accuracy: 0.9813 - val_loss: 0.1736 - val_accuracy: 0.9545
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1374 - accuracy: 0.9864 - val_loss: 0.1774 - val_accuracy: 0.9697
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9898 - val_loss: 0.1518 - val_accuracy: 0.9697
# Epoch 14/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1458 - accuracy: 0.9830 - val_loss: 0.1868 - val_accuracy: 0.9697
# Epoch 15/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1353 - accuracy: 0.9847 - val_loss: 0.1695 - val_accuracy: 0.9545
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9915 - val_loss: 0.1533 - val_accuracy: 0.9697
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1124 - accuracy: 0.9932 - val_loss: 0.1660 - val_accuracy: 0.9697
# Epoch 18/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1126 - accuracy: 0.9915 - val_loss: 0.1476 - val_accuracy: 0.9697
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1137 - accuracy: 0.9915 - val_loss: 0.1518 - val_accuracy: 0.9697
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1134 - accuracy: 0.9881 - val_loss: 0.2132 - val_accuracy: 0.9242
# Epoch 21/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1351 - accuracy: 0.9813 - val_loss: 0.1215 - val_accuracy: 0.9848
# Epoch 22/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1064 - accuracy: 0.9864 - val_loss: 0.1341 - val_accuracy: 0.9697
# Epoch 23/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 0.9915 - val_loss: 0.1522 - val_accuracy: 0.9697
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0935 - accuracy: 0.9966 - val_loss: 0.1671 - val_accuracy: 0.9545
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1004 - accuracy: 0.9898 - val_loss: 0.1418 - val_accuracy: 0.9697
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9949 - val_loss: 0.1263 - val_accuracy: 0.9697
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0868 - accuracy: 0.9966 - val_loss: 0.1328 - val_accuracy: 0.9697
# Epoch 28/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0840 - accuracy: 0.9983 - val_loss: 0.1150 - val_accuracy: 0.9697
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0813 - accuracy: 0.9983 - val_loss: 0.1225 - val_accuracy: 0.9697
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9983 - val_loss: 0.1247 - val_accuracy: 0.9697
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0801 - accuracy: 0.9966 - val_loss: 0.1207 - val_accuracy: 0.9697
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0810 - accuracy: 0.9966 - val_loss: 0.1271 - val_accuracy: 0.9697
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0795 - accuracy: 0.9966 - val_loss: 0.1187 - val_accuracy: 0.9697
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.9983 - val_loss: 0.1138 - val_accuracy: 0.9697
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0729 - accuracy: 0.9966 - val_loss: 0.1086 - val_accuracy: 0.9697
# Epoch 36/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0693 - accuracy: 0.9983 - val_loss: 0.1108 - val_accuracy: 0.9697
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0677 - accuracy: 0.9983 - val_loss: 0.1012 - val_accuracy: 0.9697
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9983 - val_loss: 0.1308 - val_accuracy: 0.9697
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0764 - accuracy: 0.9932 - val_loss: 0.1328 - val_accuracy: 0.9697
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9983 - val_loss: 0.1189 - val_accuracy: 0.9697
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9983 - val_loss: 0.1038 - val_accuracy: 0.9697
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0641 - accuracy: 0.9983 - val_loss: 0.1063 - val_accuracy: 0.9697
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9983 - val_loss: 0.0990 - val_accuracy: 0.9697
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9697
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9697
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9697
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9697
# Epoch 48/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9697
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0560 - accuracy: 0.9983 - val_loss: 0.0983 - val_accuracy: 0.9697
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9697
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9954
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1051 - accuracy: 0.9817
# Training accuracy : 0.9954
# Testing accuracy  : 0.9817
# Text(0.5, 0, 'epoch')

# %% [markdown]
# Now let's apply this classifier to one of the images,

# %%
# -- visualize one of the images

# %%
# -- create ALL the postage stamps
nrow, ncol = img.shape
stamps =

# %%
# -- predict all of these
feat_stmp = 
pred =

# %%
# -- create prediction image
pimg = 
pimg[wid:nrow-wid, wid:ncol-wid] =

# %%
# -- visualize

# %%
# -- another example

# %% [markdown]
# Let's see an example of the "feature vector" that is ultimately used for classification.

# %%
# -- create the extraction model
extractor = 

# -- get the feature vector for the various layers
fvec = 

# -- plot the output of the last dense layer

# %%
# -- plot all positive example feature vectors


# -- plot all negative example feature vectors
