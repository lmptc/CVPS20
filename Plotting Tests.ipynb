# %% [markdown]
# ###========+

# %%
# -- mount google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-66be6e4b27e9> in <module>()
#       1 # -- mount google drive
#       2 from google.colab import drive
# ----> 3 drive.mount("/content/drive")
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
#     137   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

import os
fname = os.path.join("drive", "My Drive", "cvps20", "data", "examples", "city_image.jpg")

img = plt.imread(fname);

# %%
fname
# Out:
# 'drive/My Drive/cvps20/data/examples/city_image.jpg'

# %%
ls "drive/My Drive/cvps20"
# Out:
# assignments/  data/  syllabus/  week1/  week2/  week3/  week4/

# %%
plt.imshow(img)

# %%
plt.figure(figsize=(50,50))
plt.imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plt.figure(figsize=(7,7))
x = np.arange(0.4,4,0.01)

y1 = 1/x;
y2 = 2/x;
y3 = 1/x**2;
y4 = 2/x**2;

plt.plot(x,y1, x, y2, x, y3,x, y4)
plt.ylim(0,6)
plt.xlim(0,3)

plt.legend(['y1' , 'y2' , 'y3', 'y4'])

plt.fill_between(x, np.minimum(y2, y4), np.maximum(y3,y1),
                 where= np.logical_and( y2>=y3, y1<=y4),
                 color = (0.5,0.5,0.5))

# %%
fig, ax = plt.subplots(figsize=(15,9))
x = np.arange(0.4,4,0.01)

y1 = 1/x;
y2 = 2/x;
y3 = 1/x**2;
y4 = 2/x**2;

plt.plot(x,y1, label = 'y1')
plt.plot(x,y2, label = 'y2')
plt.plot(x,y3, label = 'y3')
plt.plot(x,y4, label = 'y4')

plt.ylim(0,6)
plt.xlim(0,3)

plt.legend()

plt.fill_between(x, np.minimum(y2, y4), np.maximum(y3,y1), where= np.logical_and( y2>=y3, y1<=y4),  color = (0.8,0.8,0.8))

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.imshow(np.random.rand(50,50))

# %%
import scipy
import numpy as np

# %%
a = np.random.rand(5,5)

# %%
a
# Out:
# array([[0.75543717, 0.47392874, 0.80765055, 0.41134317, 0.8189522 ],
#        [0.52845008, 0.1949397 , 0.28825221, 0.53100356, 0.22764928],
#        [0.53985781, 0.5324051 , 0.52979341, 0.60942795, 0.83279499],
#        [0.71583699, 0.67046797, 0.72144154, 0.22756043, 0.78737806],
#        [0.07689448, 0.45243439, 0.75218824, 0.14302212, 0.79129496]])

# %%
scipy.ndimage.sum(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f48f77dc4eb7> in <module>()
# ----> 1 scipy.ndimage.sum(a)
#
# AttributeError: module 'scipy' has no attribute 'ndimage'

# %%
from scipy  import ndimage

# %%
ndimage.sum(a)
# Out:
# 13.42040512445082

# %%
sum(sum(a))
# Out:
# 13.420405124450822

# %%
np.sum(a) == ndimage.sum(a)
# Out:
# True

# %% [markdown]
# ###=========

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.filters import threshold_otsu
from scipy.ndimage.morphology import binary_erosion, binary_dilation, binary_closing, binary_fill_holes, binary_opening
import scipy.ndimage.measurements as snm
import scipy.ndimage.filters as flt
from scipy.signal import convolve2d
from numpy import linalg as LA
import cv2
from google.colab.patches import cv2_imshow

plt.rcParams["figure.figsize"] = (10, 10)
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gist_gray"

# -- define the Sobel filters
sx = np.array([[1, 0, -1], [2, 0, -2], [1, 0, -1]])
sy = np.array([[1, 2, 1], [0, 0, 0], [-1, -2, -1]])

# %%
img = plt.imread("/content/drive/MyDrive/Colab Notebooks/20200209_000729.jpg")
plt.imshow(img)

# %%
imgALum = (img[:,:,1])/255

imgAGau = flt.gaussian_filter(imgALum, 1)

fig, ax = plt.subplots(1, 3, figsize=(15, 10))
ax[0].imshow(imgALum)
ax[1].imshow(imgAGau)
ax[2].imshow(imgALum < 0.9 * imgAGau, cmap = "Greys")
fig.show()

# %%
Lx = convolve2d(imgAGau, sx)
Ly = convolve2d(imgAGau, sy)
LL = np.sqrt(Lx**2 + Ly**2)

# -- plot it
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
ax[0, 0].imshow(imgAGau)
ax[0, 1].imshow(Lx)
ax[1, 0].imshow(Ly)
ax[1, 1].imshow(LL)
fig.show()

# %%
img2 = plt.imread('/content/drive/MyDrive/cvps20/data/examples/city_image.jpg')

# %%
plt.imshow(img2)

# %%
clone = img2.copy()
cv2.rectangle(clone, (200,100), (400,200), (255,0,0), 5 )
plt.imshow( clone)

cv2.waitKey(0)

# %% [markdown]
# ###===================

# %%
import keras

# %%
import matplotlib.pyplot as plt

# %%
from keras.datasets import mnist

# %%
(x_train,_), (x_test,_) = mnist.load_data()

# %%
nimg, nrow, ncol = x_train.shape

# %%
plt.imshow(x_train[0])

# %%
y_train = x_train.copy()

# %%
from keras.models import Sequential
from keras.

# %%
model_digits = Sequential()

# %%
model_digits.add()
